# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush04H/Machine_Leaarning/blob/main/CarRental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Import Dataset**

# %%
dataset=pd.read_csv('CarRentalData.csv')
dataset.head()
# Out:
#    fuelType  rating  renterTripsTaken  reviewCount      location.city  \
# 0  GASOLINE     5.0                 1            1              Miami
# 1  GASOLINE     NaN                 0            0           Monument
# 2  GASOLINE     NaN                 0            0  Sunny Isles Beach
# 3  GASOLINE     5.0                 3            2  Sunny Isles Beach
# 4       NaN     4.8                21           15        Miami Beach
#
#   location.country  location.latitude  location.longitude location.state  \
# 0               US          25.762867          -80.189340             FL
# 1               US          39.065143         -104.833966             CO
# 2               US          25.952209          -80.120557             FL
# 3               US          25.952512          -80.119771             FL
# 4               US          25.791807          -80.128564             FL
#
#    owner.id  rate.daily   vehicle.make vehicle.model  vehicle.year  \
# 0    864946        1500    Rolls Royce         Ghost          2011
# 1  15248243        1485           Ford       Mustang          2020
# 2    864946        1400  Mercedes-Benz       G-Class          2015
# 3    864946        1200   Aston Martin    V8 Vantage          2013
# 4   9541863        1199    Lamborghini       Huracan          2019
#
#   vehicle.type
# 0          car
# 1          car
# 2          suv
# 3          car
# 4          car
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_0, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_1, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_2, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_3, *['location.latitude'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_4, *['location.city'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_5, *['location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_6, *['vehicle.make'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_7, *['vehicle.model'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_8, *[[['rating', 'renterTripsTaken'], ['renterTripsTaken', 'reviewCount'], ['reviewCount', 'location.latitude'], ['location.latitude', 'location.longitude']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_9, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_10, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_11, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_12, *['location.latitude'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_13, *['location.city', 'location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_14, *['location.state', 'vehicle.make'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_15, *['vehicle.make', 'vehicle.model'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_16, *['vehicle.model', 'vehicle.type'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_17, *['rating', 'location.city'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_18, *['rating', 'location.state'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_19, *['rating', 'vehicle.make'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_20, *['rating', 'vehicle.model'], **{'inner': 'stick'})
# chart

# %% [markdown]
# **To Check for the null values**

# %%
dataset.isnull().sum()
# Out:
# fuelType               80
# rating                521
# renterTripsTaken        0
# reviewCount             0
# location.city           0
# location.country        0
# location.latitude       0
# location.longitude      0
# location.state          0
# owner.id                0
# rate.daily              0
# vehicle.make            0
# vehicle.model           0
# vehicle.year            0
# vehicle.type            0
# dtype: int64

# %% [markdown]
# # **No Of Rows And Columns**

# %%
dataset.shape
# Out:
# (6097, 15)

# %% [markdown]
# # **Description of Data**

# %%
dataset.describe()
# Out:
#             rating  renterTripsTaken  reviewCount  location.latitude  \
# count  5576.000000       6097.000000  6097.000000        6097.000000
# mean      4.920109         33.451206    28.431852          35.511774
# std       0.180109         41.660525    34.928912           6.315087
# min       1.000000          0.000000     0.000000          21.272565
# 25%       4.900000          5.000000     4.000000          32.041299
# 50%       5.000000         18.000000    16.000000          35.182422
# 75%       5.000000         46.000000    40.000000          39.940748
# max       5.000000        395.000000   321.000000          64.893610
#
#        location.longitude      owner.id   rate.daily  vehicle.year
# count         6097.000000  6.097000e+03  6097.000000   6097.000000
# mean           -99.143961  5.797009e+06    94.456618   2015.351156
# std             20.176938  4.696837e+06    95.759326      4.013862
# min           -158.165693  5.105000e+03    20.000000   1955.000000
# 25%           -117.102528  1.506983e+06    45.000000   2014.000000
# 50%            -95.382956  4.609659e+06    69.000000   2016.000000
# 75%            -81.727800  9.468747e+06   112.000000   2018.000000
# max            -68.823637  1.581088e+07  1500.000000   2020.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_21, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_22, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_23, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_24, *['location.latitude'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_25, *[[['rating', 'renterTripsTaken'], ['renterTripsTaken', 'reviewCount'], ['reviewCount', 'location.latitude'], ['location.latitude', 'location.longitude']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_26, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_27, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_28, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_29, *['location.latitude'], **{})
# chart

# %% [markdown]
# **Dealing with the Null data**

# %%
dataset['fuelType'].fillna(method ='ffill',  inplace = True)
dataset['rating'].fillna(method ='ffill',  inplace = True)
dataset.isnull().sum()
# Out:
# fuelType              0
# rating                0
# renterTripsTaken      0
# reviewCount           0
# location.city         0
# location.country      0
# location.latitude     0
# location.longitude    0
# location.state        0
# owner.id              0
# rate.daily            0
# vehicle.make          0
# vehicle.model         0
# vehicle.year          0
# vehicle.type          0
# dtype: int64

# %% [markdown]
# # Encoding IndeDependent Variable

# %% [markdown]
# # **Encoding The Dependent Variable**

# %%
dataset['vehicle.type'].value_counts()
# Out:
# car        3659
# suv        1714
# truck       382
# minivan     232
# van         110
# Name: vehicle.type, dtype: int64

# %%
dataset.replace({'vehicle.type':{'car':0,'suv':1,'minivan':2,'truck':3,'van':4},'location.country':{'US':1}},inplace=True)
dataset.head()
# Out:
#    fuelType  rating  renterTripsTaken  reviewCount      location.city  \
# 0  GASOLINE     5.0                 1            1              Miami
# 1  GASOLINE     5.0                 0            0           Monument
# 2  GASOLINE     5.0                 0            0  Sunny Isles Beach
# 3  GASOLINE     5.0                 3            2  Sunny Isles Beach
# 4  GASOLINE     4.8                21           15        Miami Beach
#
#    location.country  location.latitude  location.longitude location.state  \
# 0                 1          25.762867          -80.189340             FL
# 1                 1          39.065143         -104.833966             CO
# 2                 1          25.952209          -80.120557             FL
# 3                 1          25.952512          -80.119771             FL
# 4                 1          25.791807          -80.128564             FL
#
#    owner.id  rate.daily   vehicle.make vehicle.model  vehicle.year  \
# 0    864946        1500    Rolls Royce         Ghost          2011
# 1  15248243        1485           Ford       Mustang          2020
# 2    864946        1400  Mercedes-Benz       G-Class          2015
# 3    864946        1200   Aston Martin    V8 Vantage          2013
# 4   9541863        1199    Lamborghini       Huracan          2019
#
#    vehicle.type
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_30, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_31, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_32, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_33, *['location.latitude'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_34, *['location.city'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_35, *['location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_36, *['vehicle.make'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_37, *['vehicle.model'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_38, *[[['rating', 'renterTripsTaken'], ['renterTripsTaken', 'reviewCount'], ['reviewCount', 'location.latitude'], ['location.latitude', 'location.longitude']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_39, *['location.country', 'rating', 'location.city'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_40, *['location.country', 'rating', 'location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_41, *['location.country', 'rating', 'vehicle.make'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_42, *['location.country', 'rating', 'vehicle.model'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_43, *['rating'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_44, *['renterTripsTaken'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_45, *['reviewCount'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_46, *['location.latitude'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_47, *['location.city', 'location.state'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_48, *['location.state', 'vehicle.make'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(_df_49, *['vehicle.make', 'vehicle.model'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_50, *['rating', 'location.city'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_51, *['rating', 'location.state'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_52, *['rating', 'vehicle.make'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_53, *['rating', 'vehicle.model'], **{'inner': 'stick'})
# chart

# %%
dataset['vehicle.type'].value_counts()
# Out:
# 0    3659
# 1    1714
# 3     382
# 2     232
# 4     110
# Name: vehicle.type, dtype: int64

# %%
x=dataset.drop(columns='vehicle.type',axis=1)
y=dataset['vehicle.type']

# %%
print(x)
# Out:
#       fuelType  rating  renterTripsTaken  reviewCount      location.city  \
# 0     GASOLINE    5.00                 1            1              Miami
# 1     GASOLINE    5.00                 0            0           Monument
# 2     GASOLINE    5.00                 0            0  Sunny Isles Beach
# 3     GASOLINE    5.00                 3            2  Sunny Isles Beach
# 4     GASOLINE    4.80                21           15        Miami Beach
# ...        ...     ...               ...          ...                ...
# 6092  GASOLINE    5.00                 6            4     Salt Lake City
# 6093  GASOLINE    4.86                 9            7     Salt Lake City
# 6094  GASOLINE    5.00                13           13            Orlando
# 6095  GASOLINE    4.98                65           54             Edmond
# 6096  GASOLINE    4.94                41           36             Irvine
#
#       location.country  location.latitude  location.longitude location.state  \
# 0                    1          25.762867          -80.189340             FL
# 1                    1          39.065143         -104.833966             CO
# 2                    1          25.952209          -80.120557             FL
# 3                    1          25.952512          -80.119771             FL
# 4                    1          25.791807          -80.128564             FL
# ...                ...                ...                 ...            ...
# 6092                 1          40.806653         -111.947767             UT
# 6093                 1          40.806919         -111.947760             UT
# 6094                 1          28.546660          -81.377734             FL
# 6095                 1          35.651699          -97.555440             OK
# 6096                 1          33.646327         -117.749031             CA
#
#       owner.id  rate.daily   vehicle.make vehicle.model  vehicle.year
# 0       864946        1500    Rolls Royce         Ghost          2011
# 1     15248243        1485           Ford       Mustang          2020
# 2       864946        1400  Mercedes-Benz       G-Class          2015
# 3       864946        1200   Aston Martin    V8 Vantage          2013
# 4      9541863        1199    Lamborghini       Huracan          2019
# ...        ...         ...            ...           ...           ...
# 6092   5558753          20       Chrysler       Sebring          2006
# 6093   5558753          20           Ford        Taurus          2006
# 6094   6598076          20           FIAT           500          2012
# 6095   7472911          20         Nissan        Altima          2009
# 6096   8853685          20         Nissan         Versa          2017
#
# [6097 rows x 14 columns]

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 6092    0
# 6093    0
# 6094    0
# 6095    0
# 6096    0
# Name: vehicle.type, Length: 6097, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0,4,8,11,12])],remainder='passthrough')
x=ct.fit_transform(x)

# %%
print(x)
# Out:
#   (0, 2)	1.0
#   (0, 552)	1.0
#   (0, 984)	1.0
#   (0, 1064)	1.0
#   (0, 1301)	1.0
#   (0, 1601)	5.0
#   (0, 1602)	1.0
#   (0, 1603)	1.0
#   (0, 1604)	1.0
#   (0, 1605)	25.762867
#   (0, 1606)	-80.18934
#   (0, 1607)	864946.0
#   (0, 1608)	1500.0
#   (0, 1609)	2011.0
#   (1, 2)	1.0
#   (1, 576)	1.0
#   (1, 980)	1.0
#   (1, 1035)	1.0
#   (1, 1390)	1.0
#   (1, 1601)	5.0
#   (1, 1604)	1.0
#   (1, 1605)	39.065143
#   (1, 1606)	-104.833966
#   (1, 1607)	15248243.0
#   (1, 1608)	1485.0
#   :	:
#   (6095, 1059)	1.0
#   (6095, 1140)	1.0
#   (6095, 1601)	4.98
#   (6095, 1602)	65.0
#   (6095, 1603)	54.0
#   (6095, 1604)	1.0
#   (6095, 1605)	35.651699
#   (6095, 1606)	-97.55544
#   (6095, 1607)	7472911.0
#   (6095, 1608)	20.0
#   (6095, 1609)	2009.0
#   (6096, 2)	1.0
#   (6096, 419)	1.0
#   (6096, 979)	1.0
#   (6096, 1059)	1.0
#   (6096, 1552)	1.0
#   (6096, 1601)	4.94
#   (6096, 1602)	41.0
#   (6096, 1603)	36.0
#   (6096, 1604)	1.0
#   (6096, 1605)	33.646327
#   (6096, 1606)	-117.749031
#   (6096, 1607)	8853685.0
#   (6096, 1608)	20.0
#   (6096, 1609)	2017.0

# %% [markdown]
# # **Split Test and Train data**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=1)

# %% [markdown]
# # **Feature scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler(with_mean=False)
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
x=sc.transform(x)

# %% [markdown]
# # **Training The Model**

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# # **Predicting of The Test Set**

# %%
y_pred=classifier.predict(X_test)

# %% [markdown]
# # **Confusion Metrics and accuracy score**

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
acc=accuracy_score(y_test, y_pred)
print('The Accuracy for the Model will be :',acc*100,'%')
# Out:
# [[891  10   0   9   1]
#  [ 22 399   0   6   0]
#  [  1   0  58   0   0]
#  [ 22   4   0  76   0]
#  [  6   1   1   4  14]]
# The Accuracy for the Model will be : 94.29508196721311 %

# %% [markdown]
# # **Making A Predictive System**

# %%
n=int(input("Enter the Number of Data Upto which u want to check the data in X_test"))
for a in range(0,n+1):
  inp=X_test[a]
  prediction=classifier.predict(inp)
  print(prediction)
  if(prediction==0):
    print("The Vehicle Rented is a Car as it is mapped with value ",prediction)
  elif(prediction==1):
    print("The Vehicle Rented is a SUV as it is mapped with value ",prediction)
  elif(prediction==2):
    print("The Vehicle Rented is a minivan as it is mapped with value ",prediction)
  elif(prediction==3):
    print("The Vehicle Rented is a truck as it is mapped with value ",prediction)
  elif(prediction==4):
    print("The Vehicle Rented is a van as it is mapped with value ",prediction)
  else:
    print('Unable to Predict')
# Out:
# Enter the Number of Data Upto which u want to check the data in X_test250
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [4]
# The Vehicle Rented is a van as it is mapped with value  [4]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [4]
# The Vehicle Rented is a van as it is mapped with value  [4]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [4]
# The Vehicle Rented is a van as it is mapped with value  [4]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [2]
# The Vehicle Rented is a minivan as it is mapped with value  [2]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [0]
# The Vehicle Rented is a Car as it is mapped with value  [0]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
# [3]
# The Vehicle Rented is a truck as it is mapped with value  [3]
# [1]
# The Vehicle Rented is a SUV as it is mapped with value  [1]
